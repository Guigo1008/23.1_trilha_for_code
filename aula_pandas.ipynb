# %% [markdown]
# <a href="https://colab.research.google.com/github/Guigo1008/23.1_trilha_for_code/blob/main/aula_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_excel("/content/db.xlsx")
dados
# Out:
#         Nome    Diretoria Linguagem Main  Numero Preferido   CR
# 0    Nicolas  Presidência           Java                10  9,7
# 1  Guilherme     Projetos            C++                 8  2,5
# 2    Mariana     Projetos         Python                13    7
# 3    Rodrigo    Marketing         Python                 9  6,4
# 4       Anna    Marketing         Python                27    6

# %%
dados["Numero Preferido"] = dados["Numero Preferido"]*3

# %%
dados.head()
# Out:
#         Nome    Diretoria Linguagem Main  Numero Preferido   CR
# 0    Nicolas  Presidência           Java                30  9,7
# 1  Guilherme     Projetos            C++                24  2,5
# 2    Mariana     Projetos         Python                39    7
# 3    Rodrigo    Marketing         Python                27  6,4
# 4       Anna    Marketing         Python                81    6

# %%
dados.describe()
# Out:
#        Numero Preferido
# count          5.000000
# mean          40.200000
# std           23.488295
# min           24.000000
# 25%           27.000000
# 50%           30.000000
# 75%           39.000000
# max           81.000000

# %%
aux = []
for i in list(dados["CR"]):
  i = str(i)
  i = i.replace(',', ".")
  i = float(i)
  aux.append(i)
aux
# Out:
# [9.7, 2.5, 7.0, 6.4, 6.0]

# %%
dados["CR"] = aux

# %%
dados
# Out:
#         Nome    Diretoria Linguagem Main  Numero Preferido   CR
# 0    Nicolas  Presidência           Java                30  9.7
# 1  Guilherme     Projetos            C++                24  2.5
# 2    Mariana     Projetos         Python                39  7.0
# 3    Rodrigo    Marketing         Python                27  6.4
# 4       Anna    Marketing         Python                81  6.0

# %%
dados[dados['CR'] >= 7.]
# Out:
#       Nome    Diretoria Linguagem Main  Numero Preferido   CR
# 0  Nicolas  Presidência           Java                30  9.7
# 2  Mariana     Projetos         Python                39  7.0

# %%
dados.to_excel("mapeamento.xlsx")

# %%
dados["Diretoria"].value_counts()
# Out:
# Projetos       2
# Marketing      2
# Presidência    1
# Name: Diretoria, dtype: int64
